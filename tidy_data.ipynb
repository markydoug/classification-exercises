# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import acquire
import prepare

# %% [markdown]
# ### 1. Attendance Data
#
# Read the data from the attendance table and calculate an attendance percentage for each student. One half day is worth 50% of a full day, and 10 tardies is equal to one absence.

# %%
attendance = pd.read_sql('''SELECT * FROM attendance;''', acquire.get_db_url('tidy_data'))

# %%
attendance
# Out:
#   Unnamed: 0 2018-01-01 2018-01-02 2018-01-03 2018-01-04 2018-01-05  \
# 0      Sally          P          T          T          H          P
# 1       Jane          A          P          T          T          T
# 2      Billy          A          T          A          A          H
# 3       John          P          T          H          P          P
#
#   2018-01-06 2018-01-07 2018-01-08
# 0          A          T          T
# 1          T          A          T
# 2          T          P          T
# 3          T          P          P

# %%
attendance.rename(columns={'Unnamed: 0':'name'}, inplace=True)

# %%
attendance.head()
# Out:
#     name 2018-01-01 2018-01-02 2018-01-03 2018-01-04 2018-01-05 2018-01-06  \
# 0  Sally          P          T          T          H          P          A
# 1   Jane          A          P          T          T          T          T
# 2  Billy          A          T          A          A          H          T
# 3   John          P          T          H          P          P          T
#
#   2018-01-07 2018-01-08
# 0          T          T
# 1          A          T
# 2          P          T
# 3          P          P

# %%
attendance = attendance.melt(id_vars='name', var_name='date', value_name='attendance')

# %%
attendance.head()
# Out:
#     name        date attendance
# 0  Sally  2018-01-01          P
# 1   Jane  2018-01-01          A
# 2  Billy  2018-01-01          A
# 3   John  2018-01-01          P
# 4  Sally  2018-01-02          T

# %%
# replace data values of attendance with floats relating to attendance
attendance['attendance'].replace({'A':0,'P':1,'T':.9,'H':0.5}, inplace = True)

# %%
attendance.groupby('name').mean()
# Out:
#        attendance
# name
# Billy      0.5250
# Jane       0.6875
# John       0.9125
# Sally      0.7625

# %% [markdown]
# ### 2. Coffee Levels
#
# a. Read the coffee_levels table.

# %%
coffee_levels = pd.read_sql('''SELECT * 
                            FROM coffee_levels;
                            ''', acquire.get_db_url('tidy_data'))

# %%
coffee_levels
# Out:
#     hour coffee_carafe  coffee_amount
# 0      8             x       0.816164
# 1      9             x       0.451018
# 2     10             x       0.843279
# 3     11             x       0.335533
# 4     12             x       0.898291
# 5     13             x       0.310711
# 6     14             x       0.507288
# 7     15             x       0.215043
# 8     16             x       0.183891
# 9     17             x       0.391560
# 10     8             y       0.189297
# 11     9             y       0.521502
# 12    10             y       0.023163
# 13    11             y       0.235529
# 14    12             y       0.017009
# 15    13             y       0.997464
# 16    14             y       0.058361
# 17    15             y       0.144644
# 18    16             y       0.544676
# 19    17             y       0.594126
# 20     8             z       0.999264
# 21     9             z       0.915990
# 22    10             z       0.144928
# 23    11             z       0.311495
# 24    12             z       0.771947
# 25    13             z       0.398520
# 26    14             z       0.864464
# 27    15             z       0.436364
# 28    16             z       0.280621
# 29    17             z       0.436677

# %% [markdown]
# b. Transform the data so that each carafe is in it's own column.

# %%
coffee_levels.pivot_table(values = 'coffee_amount', 
                          index='hour', 
                          columns='coffee_carafe')
# Out:
# coffee_carafe         x         y         z
# hour
# 8              0.816164  0.189297  0.999264
# 9              0.451018  0.521502  0.915990
# 10             0.843279  0.023163  0.144928
# 11             0.335533  0.235529  0.311495
# 12             0.898291  0.017009  0.771947
# 13             0.310711  0.997464  0.398520
# 14             0.507288  0.058361  0.864464
# 15             0.215043  0.144644  0.436364
# 16             0.183891  0.544676  0.280621
# 17             0.391560  0.594126  0.436677

# %% [markdown]
# c. Is this the best shape for the data?

# %% [markdown]
# ***No, the original data was better.***

# %% [markdown]
# ### 3. Cake Recipes
#
# a. Read the cake_recipes table. This data set contains cake tastiness scores for combinations of different recipes, oven rack positions, and oven temperatures.

# %%
cake_recipes = pd.read_sql('''SELECT * FROM cake_recipes;''', acquire.get_db_url('tidy_data'))

# %%
cake_recipes
# Out:
#   recipe:position        225        250        275        300
# 0        a:bottom  61.738655  53.912627  74.414730  98.786784
# 1           a:top  51.709751  52.009735  68.576858  50.228470
# 2        b:bottom  57.095320  61.904369  61.196980  99.248541
# 3           b:top  82.455004  95.224151  98.594881  58.169349
# 4        c:bottom  96.470207  52.001358  92.893227  65.473084
# 5           c:top  71.306308  82.795477  92.098049  53.960273
# 6        d:bottom  52.799753  58.670419  51.747686  56.183110
# 7           d:top  96.873178  76.101363  59.571620  50.971626

# %% [markdown]
# b. Tidy the data as necessary.

# %%
cake_melt = cake_recipes.melt(id_vars='recipe:position',
                 var_name='temp',
                 value_name='rate')

# %%
cake_melt.head()
# Out:
#   recipe:position temp       rate
# 0        a:bottom  225  61.738655
# 1           a:top  225  51.709751
# 2        b:bottom  225  57.095320
# 3           b:top  225  82.455004
# 4        c:bottom  225  96.470207

# %%
cake_melt[['recipe','position']] = cake_melt.recipe:position.str.split(':', expand= True)

# %%
cake_melt.drop(columns='recipe:position', inplace=True)

# %%
cake_melt.head()
# Out:
#   temp       rate recipe position
# 0  225  61.738655      a   bottom
# 1  225  51.709751      a      top
# 2  225  57.095320      b   bottom
# 3  225  82.455004      b      top
# 4  225  96.470207      c   bottom

# %% [markdown]
# c. Which recipe, on average, is the best? ***recipe b***

# %%
cake_melt.groupby('recipe').mean()
# Out:
#              rate
# recipe
# a       63.922201
# b       76.736074
# c       75.874748
# d       62.864844

# %% [markdown]
# d. Which oven temperature, on average, produces the best results? ***275***

# %%
cake_melt.groupby('temp').mean()
# Out:
#            rate
# temp
# 225   71.306022
# 250   66.577437
# 275   74.886754
# 300   66.627655

# %% [markdown]
# e. Which combination of recipe, rack position, and temperature gives the best result? ***recipe b, bottom rack, 300 degrees***

# %%
cake_melt.groupby(['recipe', 'position', 'temp']).mean()
# Out:
#                            rate
# recipe position temp
# a      bottom   225   61.738655
#                 250   53.912627
#                 275   74.414730
#                 300   98.786784
#        top      225   51.709751
#                 250   52.009735
#                 275   68.576858
#                 300   50.228470
# b      bottom   225   57.095320
#                 250   61.904369
#                 275   61.196980
#                 300   99.248541
#        top      225   82.455004
#                 250   95.224151
#                 275   98.594881
#                 300   58.169349
# c      bottom   225   96.470207
#                 250   52.001358
#                 275   92.893227
#                 300   65.473084
#        top      225   71.306308
#                 250   82.795477
#                 275   92.098049
#                 300   53.960273
# d      bottom   225   52.799753
#                 250   58.670419
#                 275   51.747686
#                 300   56.183110
#        top      225   96.873178
#                 250   76.101363
#                 275   59.571620
#                 300   50.971626

# %%
cake_melt.groupby(['recipe', 'position', 'temp']).mean().idxmax()
# Out:
# rate    (b, bottom, 300)
# dtype: object

# %% [markdown]
# ## Bonus

# %% [markdown]
# ### Billboard

# %%
billboard = pd.read_sql('''
                            SELECT * 
                            FROM billboard;
                            ''', acquire.get_db_url('tidy_data'))

# %%
billboard.head()
# Out:
#    year        artist                    track  time date.entered  wk1   wk2  \
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87  82.0
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91  87.0
# 2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08   81  70.0
# 3  2000  3 Doors Down                    Loser  4:24   2000-10-21   76  76.0
# 4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15   57  34.0
#
#     wk3   wk4   wk5  ...  wk67  wk68  wk69  wk70  wk71  wk72  wk73  wk74  \
# 0  72.0  77.0  87.0  ...  None  None  None  None  None  None  None  None
# 1  92.0   NaN   NaN  ...  None  None  None  None  None  None  None  None
# 2  68.0  67.0  66.0  ...  None  None  None  None  None  None  None  None
# 3  72.0  69.0  67.0  ...  None  None  None  None  None  None  None  None
# 4  25.0  17.0  17.0  ...  None  None  None  None  None  None  None  None
#
#    wk75  wk76
# 0  None  None
# 1  None  None
# 2  None  None
# 3  None  None
# 4  None  None
#
# [5 rows x 81 columns]

# %%
billboard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 81 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   year          317 non-null    int64
#  1   artist        317 non-null    object
#  2   track         317 non-null    object
#  3   time          317 non-null    object
#  4   date.entered  317 non-null    object
#  5   wk1           317 non-null    int64
#  6   wk2           312 non-null    float64
#  7   wk3           307 non-null    float64
#  8   wk4           300 non-null    float64
#  9   wk5           292 non-null    float64
#  10  wk6           280 non-null    float64
#  11  wk7           269 non-null    float64
#  12  wk8           260 non-null    float64
#  13  wk9           253 non-null    float64
#  14  wk10          244 non-null    float64
#  15  wk11          236 non-null    float64
#  16  wk12          222 non-null    float64
#  17  wk13          210 non-null    float64
#  18  wk14          204 non-null    float64
#  19  wk15          197 non-null    float64
#  20  wk16          182 non-null    float64
#  21  wk17          177 non-null    float64
#  22  wk18          166 non-null    float64
#  23  wk19          156 non-null    float64
#  24  wk20          146 non-null    float64
#  25  wk21          65 non-null     float64
#  26  wk22          55 non-null     float64
#  27  wk23          48 non-null     float64
#  28  wk24          46 non-null     float64
#  29  wk25          38 non-null     float64
#  30  wk26          36 non-null     float64
#  31  wk27          29 non-null     float64
#  32  wk28          24 non-null     float64
#  33  wk29          20 non-null     float64
#  34  wk30          20 non-null     float64
#  35  wk31          19 non-null     float64
#  36  wk32          18 non-null     float64
#  37  wk33          12 non-null     float64
#  38  wk34          10 non-null     float64
#  39  wk35          9 non-null      float64
#  40  wk36          9 non-null      float64
#  41  wk37          9 non-null      float64
#  42  wk38          8 non-null      float64
#  43  wk39          8 non-null      float64
#  44  wk40          7 non-null      float64
#  45  wk41          7 non-null      float64
#  46  wk42          6 non-null      float64
#  47  wk43          6 non-null      float64
#  48  wk44          6 non-null      float64
#  49  wk45          5 non-null      float64
#  50  wk46          5 non-null      float64
#  51  wk47          5 non-null      float64
#  52  wk48          4 non-null      float64
#  53  wk49          4 non-null      float64
#  54  wk50          4 non-null      float64
#  55  wk51          4 non-null      float64
#  56  wk52          4 non-null      float64
#  57  wk53          4 non-null      float64
#  58  wk54          2 non-null      float64
#  59  wk55          2 non-null      float64
#  60  wk56          2 non-null      float64
#  61  wk57          2 non-null      float64
#  62  wk58          2 non-null      float64
#  63  wk59          2 non-null      float64
#  64  wk60          2 non-null      float64
#  65  wk61          2 non-null      float64
#  66  wk62          2 non-null      float64
#  67  wk63          2 non-null      float64
#  68  wk64          2 non-null      float64
#  69  wk65          1 non-null      float64
#  70  wk66          0 non-null      object
#  71  wk67          0 non-null      object
#  72  wk68          0 non-null      object
#  73  wk69          0 non-null      object
#  74  wk70          0 non-null      object
#  75  wk71          0 non-null      object
#  76  wk72          0 non-null      object
#  77  wk73          0 non-null      object
#  78  wk74          0 non-null      object
#  79  wk75          0 non-null      object
#  80  wk76          0 non-null      object
# dtypes: float64(64), int64(2), object(15)
# memory usage: 200.7+ KB

# %%
billboard.columns = billboard.columns[:5].tolist() + list(range(1,77))

# %%
billboard
# Out:
#      year            artist                    track  time date.entered   1  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26  87
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02  91
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08  81
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21  76
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15  57
# ..    ...               ...                      ...   ...          ...  ..
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29  86
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01  85
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18  95
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02  99
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29  60
#
#         2     3     4     5  ...    67    68    69    70    71    72    73  \
# 0    82.0  72.0  77.0  87.0  ...  None  None  None  None  None  None  None
# 1    87.0  92.0   NaN   NaN  ...  None  None  None  None  None  None  None
# 2    70.0  68.0  67.0  66.0  ...  None  None  None  None  None  None  None
# 3    76.0  72.0  69.0  67.0  ...  None  None  None  None  None  None  None
# 4    34.0  25.0  17.0  17.0  ...  None  None  None  None  None  None  None
# ..    ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...   ...
# 312  83.0  77.0  74.0  83.0  ...  None  None  None  None  None  None  None
# 313  83.0  83.0  82.0  81.0  ...  None  None  None  None  None  None  None
# 314  94.0  91.0  85.0  84.0  ...  None  None  None  None  None  None  None
# 315  99.0   NaN   NaN   NaN  ...  None  None  None  None  None  None  None
# 316  37.0  29.0  24.0  22.0  ...  None  None  None  None  None  None  None
#
#        74    75    76
# 0    None  None  None
# 1    None  None  None
# 2    None  None  None
# 3    None  None  None
# 4    None  None  None
# ..    ...   ...   ...
# 312  None  None  None
# 313  None  None  None
# 314  None  None  None
# 315  None  None  None
# 316  None  None  None
#
# [317 rows x 81 columns]

# %%
billboard_melt = billboard.melt(id_vars=billboard.columns[:5],
                               var_name='week',
                               value_name='rating')

billboard_melt.head()
# Out:
#    year        artist                    track  time date.entered week rating
# 0  2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26    1     87
# 1  2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02    1     91
# 2  2000  3 Doors Down               Kryptonite  3:53   2000-04-08    1     81
# 3  2000  3 Doors Down                    Loser  4:24   2000-10-21    1     76
# 4  2000      504 Boyz            Wobble Wobble  3:35   2000-04-15    1     57

# %%
billboard_melt.groupby('artist').rating.mean().idxmax()
# Out:
# 'Fragma'

# %% [markdown]
# ### Gapminder1

# %%
gapminder1 = pd.read_sql('''
                            SELECT * 
                            FROM gapminder1;
                            ''', acquire.get_db_url('tidy_data'))

# %%
gapminder1.head()
# Out:
#    year      country measure  measurement
# 0  1955  Afghanistan     pop    8891209.0
# 1  1960  Afghanistan     pop    9829450.0
# 2  1965  Afghanistan     pop   10997885.0
# 3  1970  Afghanistan     pop   12430623.0
# 4  1975  Afghanistan     pop   14132019.0

# %%
gapminder1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2079 entries, 0 to 2078
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         2079 non-null   int64
#  1   country      2079 non-null   object
#  2   measure      2079 non-null   object
#  3   measurement  2079 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 65.1+ KB

# %%
gapminder1.measure.unique()
# Out:
# array(['pop', 'life_expect', 'fertility'], dtype=object)

# %%
gapminder1.pivot_table(values='measurement',
                      index=['country','year'],
                      columns='measure').reset_index()
# Out:
# measure      country  year  fertility  life_expect         pop
# 0        Afghanistan  1955     7.7000       30.332   8891209.0
# 1        Afghanistan  1960     7.7000       31.997   9829450.0
# 2        Afghanistan  1965     7.7000       34.020  10997885.0
# 3        Afghanistan  1970     7.7000       36.088  12430623.0
# 4        Afghanistan  1975     7.7000       38.438  14132019.0
# ..               ...   ...        ...          ...         ...
# 688        Venezuela  1985     3.6485       70.190  16997509.0
# 689        Venezuela  1990     3.2500       71.150  19325222.0
# 690        Venezuela  1995     2.9415       72.146  21555902.0
# 691        Venezuela  2000     2.7230       72.766  23542649.0
# 692        Venezuela  2005     2.5470       73.747  25375281.0
#
# [693 rows x 5 columns]

# %% [markdown]
# ### Gapminder2

# %%
gapminder2 = pd.read_sql('''
                            SELECT * 
                            FROM gapminder2;
                            ''', acquire.get_db_url('tidy_data'))

# %%
gapminder2.head()
# Out:
#        country  life_expect_1955  life_expect_1960  life_expect_1965  \
# 0  Afghanistan            30.332            31.997            34.020
# 1    Argentina            64.399            65.142            65.634
# 2        Aruba            64.381            66.606            68.336
# 3    Australia            70.330            70.930            71.100
# 4      Austria            67.480            69.540            70.140
#
#    life_expect_1970  life_expect_1975  life_expect_1980  life_expect_1985  \
# 0            36.088            38.438            39.854            40.822
# 1            67.065            68.481            69.942            70.774
# 2            70.941            71.830            74.116            74.494
# 3            71.930            73.490            74.740            76.320
# 4            70.630            72.170            73.180            74.940
#
#    life_expect_1990  life_expect_1995  ...  pop_1960  pop_1965  pop_1970  \
# 0            41.674            41.763  ...   9829450  10997885  12430623
# 1            71.868            73.275  ...  20616009  22283100  23962313
# 2            74.108            73.011  ...     57203     59020     59039
# 3            77.560            78.830  ...  10361273  11439384  12660160
# 4            76.040            77.510  ...   7047437   7270889   7467086
#
#    pop_1975  pop_1980  pop_1985  pop_1990  pop_1995  pop_2000  pop_2005
# 0  14132019  15112149  13796928  14669339  20881480  23898198  29928987
# 1  26081880  28369799  30675059  33022202  35311049  37497728  39537943
# 2     59390     60266     64129     66653     67836     69539     71566
# 3  13771400  14615900  15788300  17022133  18116171  19164620  20090437
# 4   7578903   7549433   7559776   7722953   8047433   8113413   8184691
#
# [5 rows x 23 columns]

# %%
gapminder2_melt = gapminder2.melt(id_vars='country',
                                 var_name='measure_year',
                                 value_name='measurement')

gapminder2_melt
# Out:
#              country      measure_year   measurement
# 0        Afghanistan  life_expect_1955  3.033200e+01
# 1          Argentina  life_expect_1955  6.439900e+01
# 2              Aruba  life_expect_1955  6.438100e+01
# 3          Australia  life_expect_1955  7.033000e+01
# 4            Austria  life_expect_1955  6.748000e+01
# ...              ...               ...           ...
# 1381     Switzerland          pop_2005  7.489370e+06
# 1382          Turkey          pop_2005  6.966056e+07
# 1383  United Kingdom          pop_2005  6.044146e+07
# 1384   United States          pop_2005  2.957341e+08
# 1385       Venezuela          pop_2005  2.537528e+07
#
# [1386 rows x 3 columns]

# %%
gapminder2_melt.measure_year.str.rsplit("_", n =1, expand= True)
# Out:
#                 0     1
# 0     life_expect  1955
# 1     life_expect  1955
# 2     life_expect  1955
# 3     life_expect  1955
# 4     life_expect  1955
# ...           ...   ...
# 1381          pop  2005
# 1382          pop  2005
# 1383          pop  2005
# 1384          pop  2005
# 1385          pop  2005
#
# [1386 rows x 2 columns]

# %%
gapminder2_melt[['measure','year']] = gapminder2_melt.measure_year.str.rsplit("_", n =1, expand= True)

# %%
gapminder2_melt.drop(columns='measure_year')
# Out:
#              country   measurement      measure  year
# 0        Afghanistan  3.033200e+01  life_expect  1955
# 1          Argentina  6.439900e+01  life_expect  1955
# 2              Aruba  6.438100e+01  life_expect  1955
# 3          Australia  7.033000e+01  life_expect  1955
# 4            Austria  6.748000e+01  life_expect  1955
# ...              ...           ...          ...   ...
# 1381     Switzerland  7.489370e+06          pop  2005
# 1382          Turkey  6.966056e+07          pop  2005
# 1383  United Kingdom  6.044146e+07          pop  2005
# 1384   United States  2.957341e+08          pop  2005
# 1385       Venezuela  2.537528e+07          pop  2005
#
# [1386 rows x 4 columns]

# %%
gapminder2_melt.pivot_table(values='measurement',
                      index=['country','year'],
                      columns='measure').reset_index()
# Out:
# measure      country  year  life_expect         pop
# 0        Afghanistan  1955       30.332   8891209.0
# 1        Afghanistan  1960       31.997   9829450.0
# 2        Afghanistan  1965       34.020  10997885.0
# 3        Afghanistan  1970       36.088  12430623.0
# 4        Afghanistan  1975       38.438  14132019.0
# ..               ...   ...          ...         ...
# 688        Venezuela  1985       70.190  16997509.0
# 689        Venezuela  1990       71.150  19325222.0
# 690        Venezuela  1995       72.146  21555902.0
# 691        Venezuela  2000       72.766  23542649.0
# 692        Venezuela  2005       73.747  25375281.0
#
# [693 rows x 4 columns]
